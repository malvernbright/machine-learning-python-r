# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('House_Price.csv', header=0)

# %%
df.shape
# Out:
# (506, 19)

# %%
df.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 0   24.0     0.00632       32.31     0.538     6.575  65.2   4.35   3.81
# 1   21.6     0.02731       37.07     0.469     6.421  78.9   4.99   4.70
# 2   34.7     0.02729       37.07     0.469     7.185  61.1   5.03   4.86
# 3   33.4     0.03237       32.18     0.458     6.998  45.8   6.21   5.93
# 4   36.2     0.06905       32.18     0.458     7.147  54.2   6.16   5.86
#
#    dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 0   4.18   4.01      24.7       4.98     YES       5.480      11.1920
# 1   5.12   5.06      22.2       9.14      NO       7.332      12.1728
# 2   5.01   4.97      22.2       4.03      NO       7.394     101.1200
# 3   6.16   5.96      21.3       2.94     YES       9.268      11.2672
# 4   6.37   5.86      21.3       5.33      NO       8.824      11.2896
#
#   waterbody  rainfall bus_ter     parks
# 0     River        23     YES  0.049347
# ...

# %%
df.describe()
# Out:
#             price  crime_rate  resid_area    air_qual    room_num         age  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    22.528854    3.613524   41.136779    0.554695    6.284634   68.574901
# std      9.182176    8.601545    6.860353    0.115878    0.702617   28.148861
# min      5.000000    0.006320   30.460000    0.385000    3.561000    2.900000
# 25%     17.025000    0.082045   35.190000    0.449000    5.885500   45.025000
# 50%     21.200000    0.256510   39.690000    0.538000    6.208500   77.500000
# 75%     25.000000    3.677083   48.100000    0.624000    6.623500   94.075000
# max     50.000000   88.976200   57.740000    0.871000    8.780000  100.000000
#
#             dist1       dist2       dist3       dist4    teachers   poor_prop  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.971996    3.628775    3.960672    3.618972   21.544466   12.653063
# ...

# %%
sns.jointplot(x='n_hot_rooms', y='price', data=df)

# %%
sns.jointplot(x='crime_rate', y='price', data=df)

# %%
sns.jointplot(x='rainfall', y='price', data=df)

# %%
sns.countplot(x="airport", data=df)
# Out:
# <Axes: xlabel='airport', ylabel='count'>

# %%
df.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 0   24.0     0.00632       32.31     0.538     6.575  65.2   4.35   3.81
# 1   21.6     0.02731       37.07     0.469     6.421  78.9   4.99   4.70
# 2   34.7     0.02729       37.07     0.469     7.185  61.1   5.03   4.86
# 3   33.4     0.03237       32.18     0.458     6.998  45.8   6.21   5.93
# 4   36.2     0.06905       32.18     0.458     7.147  54.2   6.16   5.86
#
#    dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 0   4.18   4.01      24.7       4.98     YES       5.480      11.1920
# 1   5.12   5.06      22.2       9.14      NO       7.332      12.1728
# 2   5.01   4.97      22.2       4.03      NO       7.394     101.1200
# 3   6.16   5.96      21.3       2.94     YES       9.268      11.2672
# 4   6.37   5.86      21.3       5.33      NO       8.824      11.2896
#
#   waterbody  rainfall bus_ter     parks
# 0     River        23     YES  0.049347
# ...

# %%
sns.countplot(x="waterbody", data=df)
# Out:
# <Axes: xlabel='waterbody', ylabel='count'>

# %%
sns.countplot(x="bus_ter", data=df)
# Out:
# <Axes: xlabel='bus_ter', ylabel='count'>

# %%
df.describe()
# Out:
#             price  crime_rate  resid_area    air_qual    room_num         age  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    22.528854    3.613524   41.136779    0.554695    6.284634   68.574901
# std      9.182176    8.601545    6.860353    0.115878    0.702617   28.148861
# min      5.000000    0.006320   30.460000    0.385000    3.561000    2.900000
# 25%     17.025000    0.082045   35.190000    0.449000    5.885500   45.025000
# 50%     21.200000    0.256510   39.690000    0.538000    6.208500   77.500000
# 75%     25.000000    3.677083   48.100000    0.624000    6.623500   94.075000
# max     50.000000   88.976200   57.740000    0.871000    8.780000  100.000000
#
#             dist1       dist2       dist3       dist4    teachers   poor_prop  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.971996    3.628775    3.960672    3.618972   21.544466   12.653063
# ...

# %% [markdown]
# ## Observations
# - Missing values in
#   - n_hos_beds
#   - waterbody
# - Skewness or outliers in
#   - crime_rate
# - Outliers in:
#   - n_hot_rooms
#   - rainfall
# - Bus ter has only a 'Yes' value

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   price        506 non-null    float64
#  1   crime_rate   506 non-null    float64
#  2   resid_area   506 non-null    float64
#  3   air_qual     506 non-null    float64
#  4   room_num     506 non-null    float64
#  5   age          506 non-null    float64
#  6   dist1        506 non-null    float64
#  7   dist2        506 non-null    float64
#  8   dist3        506 non-null    float64
#  9   dist4        506 non-null    float64
#  10  teachers     506 non-null    float64
#  11  poor_prop    506 non-null    float64
#  12  airport      506 non-null    object
#  13  n_hos_beds   498 non-null    float64
#  14  n_hot_rooms  506 non-null    float64
#  15  waterbody    351 non-null    object
#  16  rainfall     506 non-null    int64
#  17  bus_ter      506 non-null    object
# ...

# %%
np.percentile(df.n_hot_rooms, [99])
# Out:
# array([15.39952])

# %%
np.percentile(df.n_hot_rooms, [99])[0]
# Out:
# np.float64(15.39952)

# %%
uv = np.percentile(df.n_hot_rooms, [99])[0]

# %%
df[(df.n_hot_rooms > uv)]
# Out:
#      price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 2     34.7     0.02729       37.07    0.4690     7.185  61.1   5.03   4.86
# 166   50.0     2.01019       49.58    0.6050     7.929  96.2   2.11   1.91
# 204   50.0     0.02009       32.68    0.4161     8.034  31.9   5.41   4.80
# 267   50.0     0.57834       33.97    0.5750     8.297  67.0   2.60   2.13
# 369   50.0     5.66998       48.10    0.6310     6.683  96.8   1.55   1.28
# 423   13.4     7.05042       48.10    0.6140     6.103  85.1   2.08   1.80
#
#      dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 2     5.01   4.97      22.2       4.03      NO       7.394       101.12
# 166   2.31   1.86      25.3       3.70     YES       8.300        15.40
# 204   5.28   4.99      25.3       2.88     YES       8.900        15.40
# 267   2.43   2.52      27.0       7.44     YES       8.000        15.40
# 369   1.65   0.94      19.8       3.73     YES       6.700        15.40
# ...

# %%
# df.n_hot_rooms[(df.n_hot_rooms > 3*uv)] = 3*uv
df.loc[df.n_hot_rooms > 3*uv, 'n_hot_rooms'] = 3*uv

# %%
df[(df.n_hot_rooms > uv)]
# Out:
#      price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 2     34.7     0.02729       37.07    0.4690     7.185  61.1   5.03   4.86
# 166   50.0     2.01019       49.58    0.6050     7.929  96.2   2.11   1.91
# 204   50.0     0.02009       32.68    0.4161     8.034  31.9   5.41   4.80
# 267   50.0     0.57834       33.97    0.5750     8.297  67.0   2.60   2.13
# 369   50.0     5.66998       48.10    0.6310     6.683  96.8   1.55   1.28
# 423   13.4     7.05042       48.10    0.6140     6.103  85.1   2.08   1.80
#
#      dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 2     5.01   4.97      22.2       4.03      NO       7.394     46.19856
# 166   2.31   1.86      25.3       3.70     YES       8.300     15.40000
# 204   5.28   4.99      25.3       2.88     YES       8.900     15.40000
# 267   2.43   2.52      27.0       7.44     YES       8.000     15.40000
# 369   1.65   0.94      19.8       3.73     YES       6.700     15.40000
# ...

# %%
np.percentile(df.rainfall, [1])[0]
# Out:
# np.float64(20.0)

# %%
lv = np.percentile(df.rainfall, [1])[0]

# %%
df[(df.rainfall < lv)]
# Out:
#      price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 213   28.1     0.14052       40.59     0.489     6.375  32.3   4.11   3.92
#
#      dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 213   4.18   3.57      21.4       9.38     YES       7.562      10.2248
#
#     waterbody  rainfall bus_ter     parks
# 213       NaN         3     YES  0.044019

# %%
df.loc[df.rainfall < .3*lv, 'rainfall'] = .3*lv

# %%
df[(df.rainfall < lv)]
# Out:
#      price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 213   28.1     0.14052       40.59     0.489     6.375  32.3   4.11   3.92
#
#      dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 213   4.18   3.57      21.4       9.38     YES       7.562      10.2248
#
#     waterbody  rainfall bus_ter     parks
# 213       NaN         6     YES  0.044019

# %%
sns.jointplot(x='crime_rate', y='price', data=df)

# %%
df.describe()
# Out:
#             price  crime_rate  resid_area    air_qual    room_num         age  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    22.528854    3.613524   41.136779    0.554695    6.284634   68.574901
# std      9.182176    8.601545    6.860353    0.115878    0.702617   28.148861
# min      5.000000    0.006320   30.460000    0.385000    3.561000    2.900000
# 25%     17.025000    0.082045   35.190000    0.449000    5.885500   45.025000
# 50%     21.200000    0.256510   39.690000    0.538000    6.208500   77.500000
# 75%     25.000000    3.677083   48.100000    0.624000    6.623500   94.075000
# max     50.000000   88.976200   57.740000    0.871000    8.780000  100.000000
#
#             dist1       dist2       dist3       dist4    teachers   poor_prop  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.971996    3.628775    3.960672    3.618972   21.544466   12.653063
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   price        506 non-null    float64
#  1   crime_rate   506 non-null    float64
#  2   resid_area   506 non-null    float64
#  3   air_qual     506 non-null    float64
#  4   room_num     506 non-null    float64
#  5   age          506 non-null    float64
#  6   dist1        506 non-null    float64
#  7   dist2        506 non-null    float64
#  8   dist3        506 non-null    float64
#  9   dist4        506 non-null    float64
#  10  teachers     506 non-null    float64
#  11  poor_prop    506 non-null    float64
#  12  airport      506 non-null    object
#  13  n_hos_beds   498 non-null    float64
#  14  n_hot_rooms  506 non-null    float64
#  15  waterbody    351 non-null    object
#  16  rainfall     506 non-null    int64
#  17  bus_ter      506 non-null    object
# ...

# %%
df.n_hos_beds = df.n_hos_beds.fillna(df.n_hos_beds.mean())

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   price        506 non-null    float64
#  1   crime_rate   506 non-null    float64
#  2   resid_area   506 non-null    float64
#  3   air_qual     506 non-null    float64
#  4   room_num     506 non-null    float64
#  5   age          506 non-null    float64
#  6   dist1        506 non-null    float64
#  7   dist2        506 non-null    float64
#  8   dist3        506 non-null    float64
#  9   dist4        506 non-null    float64
#  10  teachers     506 non-null    float64
#  11  poor_prop    506 non-null    float64
#  12  airport      506 non-null    object
#  13  n_hos_beds   506 non-null    float64
#  14  n_hot_rooms  506 non-null    float64
#  15  waterbody    351 non-null    object
#  16  rainfall     506 non-null    int64
#  17  bus_ter      506 non-null    object
# ...

# %%
df.waterbody = df.waterbody.fillna('None')

# %%
# df = df.fillna(df.select_dtypes(include=['int64', 'float64']).mean()).fillna('None')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   price        506 non-null    float64
#  1   crime_rate   506 non-null    float64
#  2   resid_area   506 non-null    float64
#  3   air_qual     506 non-null    float64
#  4   room_num     506 non-null    float64
#  5   age          506 non-null    float64
#  6   dist1        506 non-null    float64
#  7   dist2        506 non-null    float64
#  8   dist3        506 non-null    float64
#  9   dist4        506 non-null    float64
#  10  teachers     506 non-null    float64
#  11  poor_prop    506 non-null    float64
#  12  airport      506 non-null    object
#  13  n_hos_beds   506 non-null    float64
#  14  n_hot_rooms  506 non-null    float64
#  15  waterbody    506 non-null    object
#  16  rainfall     506 non-null    int64
#  17  bus_ter      506 non-null    object
# ...

# %%
sns.jointplot(x='crime_rate', y='price', data=df)

# %%
df.crime_rate = np.log(1 + df.crime_rate) # log transformation

# %%
sns.jointplot(x='crime_rate', y='price', data=df)

# %%
df['avg_dist'] = (df.dist1 + df.dist2 + df.dist3 + df.dist4) / 4

# %%
df.describe()
# Out:
#             price  crime_rate  resid_area    air_qual    room_num         age  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    22.528854    0.813418   41.136779    0.554695    6.284634   68.574901
# std      9.182176    1.022731    6.860353    0.115878    0.702617   28.148861
# min      5.000000    0.006300   30.460000    0.385000    3.561000    2.900000
# 25%     17.025000    0.078853   35.190000    0.449000    5.885500   45.025000
# 50%     21.200000    0.228336   39.690000    0.538000    6.208500   77.500000
# 75%     25.000000    1.542674   48.100000    0.624000    6.623500   94.075000
# max     50.000000    4.499545   57.740000    0.871000    8.780000  100.000000
#
#             dist1       dist2       dist3       dist4    teachers   poor_prop  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.971996    3.628775    3.960672    3.618972   21.544466   12.653063
# ...

# %%
del df['dist1']
del df['dist2']
del df['dist3']
del df['dist4']

# %%
df.describe()
# Out:
#             price  crime_rate  resid_area    air_qual    room_num         age  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    22.528854    0.813418   41.136779    0.554695    6.284634   68.574901
# std      9.182176    1.022731    6.860353    0.115878    0.702617   28.148861
# min      5.000000    0.006300   30.460000    0.385000    3.561000    2.900000
# 25%     17.025000    0.078853   35.190000    0.449000    5.885500   45.025000
# 50%     21.200000    0.228336   39.690000    0.538000    6.208500   77.500000
# 75%     25.000000    1.542674   48.100000    0.624000    6.623500   94.075000
# max     50.000000    4.499545   57.740000    0.871000    8.780000  100.000000
#
#          teachers   poor_prop  n_hos_beds  n_hot_rooms    rainfall  \
# count  506.000000  506.000000  506.000000   506.000000  506.000000
# mean    21.544466   12.653063    7.899767    12.864050   39.187747
# ...

# %%
del df['bus_ter']

# %%
df.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  teachers  \
# 0   24.0    0.006300       32.31     0.538     6.575  65.2      24.7
# 1   21.6    0.026944       37.07     0.469     6.421  78.9      22.2
# 2   34.7    0.026924       37.07     0.469     7.185  61.1      22.2
# 3   33.4    0.031857       32.18     0.458     6.998  45.8      21.3
# 4   36.2    0.066770       32.18     0.458     7.147  54.2      21.3
#
#    poor_prop airport  n_hos_beds  n_hot_rooms waterbody  rainfall     parks  \
# 0       4.98     YES       5.480     11.19200     River        23  0.049347
# 1       9.14      NO       7.332     12.17280      Lake        42  0.046146
# 2       4.03      NO       7.394     46.19856      None        38  0.045764
# 3       2.94     YES       9.268     11.26720      Lake        45  0.047151
# 4       5.33      NO       8.824     11.28960      Lake        55  0.039474
#
#    avg_dist
# 0    4.0875
# 1    4.9675
# 2    4.9675
# 3    6.0650
# 4    6.0625

# %%
# Dummy variables
df = pd.get_dummies(df, columns=['airport', 'waterbody'], drop_first=True, dtype=int)

# %%
df.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  teachers  \
# 0   24.0    0.006300       32.31     0.538     6.575  65.2      24.7
# 1   21.6    0.026944       37.07     0.469     6.421  78.9      22.2
# 2   34.7    0.026924       37.07     0.469     7.185  61.1      22.2
# 3   33.4    0.031857       32.18     0.458     6.998  45.8      21.3
# 4   36.2    0.066770       32.18     0.458     7.147  54.2      21.3
#
#    poor_prop  n_hos_beds  n_hot_rooms  rainfall     parks  avg_dist  \
# 0       4.98       5.480     11.19200        23  0.049347    4.0875
# 1       9.14       7.332     12.17280        42  0.046146    4.9675
# 2       4.03       7.394     46.19856        38  0.045764    4.9675
# 3       2.94       9.268     11.26720        45  0.047151    6.0650
# 4       5.33       8.824     11.28960        55  0.039474    6.0625
#
#    airport_YES  waterbody_Lake and River  waterbody_None  waterbody_River
# ...

# %%
df['waterbody_lake_and_river'] = df['waterbody_Lake and River']

# %%
df.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  teachers  \
# 0   24.0    0.006300       32.31     0.538     6.575  65.2      24.7
# 1   21.6    0.026944       37.07     0.469     6.421  78.9      22.2
# 2   34.7    0.026924       37.07     0.469     7.185  61.1      22.2
# 3   33.4    0.031857       32.18     0.458     6.998  45.8      21.3
# 4   36.2    0.066770       32.18     0.458     7.147  54.2      21.3
#
#    poor_prop  n_hos_beds  n_hot_rooms  rainfall     parks  avg_dist  \
# 0       4.98       5.480     11.19200        23  0.049347    4.0875
# 1       9.14       7.332     12.17280        42  0.046146    4.9675
# 2       4.03       7.394     46.19856        38  0.045764    4.9675
# 3       2.94       9.268     11.26720        45  0.047151    6.0650
# 4       5.33       8.824     11.28960        55  0.039474    6.0625
#
#    airport_YES  waterbody_Lake and River  waterbody_None  waterbody_River  \
# ...

# %%
df.describe()
# Out:
#             price  crime_rate  resid_area    air_qual    room_num         age  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    22.528854    0.813418   41.136779    0.554695    6.284634   68.574901
# std      9.182176    1.022731    6.860353    0.115878    0.702617   28.148861
# min      5.000000    0.006300   30.460000    0.385000    3.561000    2.900000
# 25%     17.025000    0.078853   35.190000    0.449000    5.885500   45.025000
# 50%     21.200000    0.228336   39.690000    0.538000    6.208500   77.500000
# 75%     25.000000    1.542674   48.100000    0.624000    6.623500   94.075000
# max     50.000000    4.499545   57.740000    0.871000    8.780000  100.000000
#
#          teachers   poor_prop  n_hos_beds  n_hot_rooms    rainfall  \
# count  506.000000  506.000000  506.000000   506.000000  506.000000
# mean    21.544466   12.653063    7.899767    12.864050   39.187747
# ...

# %%
del df['waterbody_Lake and River']

# %%
df.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  teachers  \
# 0   24.0    0.006300       32.31     0.538     6.575  65.2      24.7
# 1   21.6    0.026944       37.07     0.469     6.421  78.9      22.2
# 2   34.7    0.026924       37.07     0.469     7.185  61.1      22.2
# 3   33.4    0.031857       32.18     0.458     6.998  45.8      21.3
# 4   36.2    0.066770       32.18     0.458     7.147  54.2      21.3
#
#    poor_prop  n_hos_beds  n_hot_rooms  rainfall     parks  avg_dist  \
# 0       4.98       5.480     11.19200        23  0.049347    4.0875
# 1       9.14       7.332     12.17280        42  0.046146    4.9675
# 2       4.03       7.394     46.19856        38  0.045764    4.9675
# 3       2.94       9.268     11.26720        45  0.047151    6.0650
# 4       5.33       8.824     11.28960        55  0.039474    6.0625
#
#    airport_YES  waterbody_None  waterbody_River  waterbody_lake_and_river
# ...

# %%
df.describe()
# Out:
#             price  crime_rate  resid_area    air_qual    room_num         age  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    22.528854    0.813418   41.136779    0.554695    6.284634   68.574901
# std      9.182176    1.022731    6.860353    0.115878    0.702617   28.148861
# min      5.000000    0.006300   30.460000    0.385000    3.561000    2.900000
# 25%     17.025000    0.078853   35.190000    0.449000    5.885500   45.025000
# 50%     21.200000    0.228336   39.690000    0.538000    6.208500   77.500000
# 75%     25.000000    1.542674   48.100000    0.624000    6.623500   94.075000
# max     50.000000    4.499545   57.740000    0.871000    8.780000  100.000000
#
#          teachers   poor_prop  n_hos_beds  n_hot_rooms    rainfall  \
# count  506.000000  506.000000  506.000000   506.000000  506.000000
# mean    21.544466   12.653063    7.899767    12.864050   39.187747
# ...

# %%
df.corr()
# Out:
#                              price  crime_rate  resid_area  air_qual  \
# price                     1.000000   -0.466527   -0.484754 -0.429300
# crime_rate               -0.466527    1.000000    0.660283  0.707587
# resid_area               -0.484754    0.660283    1.000000  0.763651
# air_qual                 -0.429300    0.707587    0.763651  1.000000
# room_num                  0.696304   -0.288784   -0.391676 -0.302188
# age                      -0.377999    0.559591    0.644779  0.731470
# teachers                  0.505655   -0.390052   -0.383248 -0.188933
# poor_prop                -0.740836    0.608970    0.603800  0.590879
# n_hos_beds                0.108880   -0.004089    0.005799 -0.049553
# n_hot_rooms               0.017007    0.056570   -0.003761  0.007238
# rainfall                 -0.047200    0.082151    0.055845  0.091956
# parks                    -0.391574    0.638951    0.707635  0.915544
# avg_dist                  0.249289   -0.586371   -0.708022 -0.769247
# ...

# %%
del df['parks']

# %%
df.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  teachers  \
# 0   24.0    0.006300       32.31     0.538     6.575  65.2      24.7
# 1   21.6    0.026944       37.07     0.469     6.421  78.9      22.2
# 2   34.7    0.026924       37.07     0.469     7.185  61.1      22.2
# 3   33.4    0.031857       32.18     0.458     6.998  45.8      21.3
# 4   36.2    0.066770       32.18     0.458     7.147  54.2      21.3
#
#    poor_prop  n_hos_beds  n_hot_rooms  rainfall  avg_dist  airport_YES  \
# 0       4.98       5.480     11.19200        23    4.0875            1
# 1       9.14       7.332     12.17280        42    4.9675            0
# 2       4.03       7.394     46.19856        38    4.9675            0
# 3       2.94       9.268     11.26720        45    6.0650            1
# 4       5.33       8.824     11.28960        55    6.0625            0
#
#    waterbody_None  waterbody_River  waterbody_lake_and_river
# 0               0                1                         0
# ...

# %% [markdown]
# # Import Statsmodels

# %%
import statsmodels.api as sn

# %%
X = sn.add_constant(df['room_num'])

# %%
lm = sn.OLS(df['price'], X).fit() # OLS: Ordinary Least Squares, a method for estimating the unknown parameters in a linear regression model. and lm is the fitted model object that contains the results of the regression analysis.

# %%
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.485
# Model:                            OLS   Adj. R-squared:                  0.484
# Method:                 Least Squares   F-statistic:                     474.3
# Date:                Thu, 19 Mar 2026   Prob (F-statistic):           1.31e-74
# Time:                        00:41:13   Log-Likelihood:                -1671.6
# No. Observations:                 506   AIC:                             3347.
# Df Residuals:                     504   BIC:                             3356.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -34.6592      2.642    -13.118      0.000     -39.850     -29.468
# ...

# %% [markdown]
# # Another way is to user sklearn

# %%
from sklearn.linear_model import LinearRegression

# %%
y = df['price']

# %%
X = df[['room_num']]

# %%
lm2 = LinearRegression()

# %%
lm2.fit(X, y)
# Out:
# LinearRegression()

# %%
print(lm2.intercept_, lm2.coef_)
# Out:
# -34.6592431230972 [9.09966966]

# %%
help(lm2)
# Out:
# Help on LinearRegression in module sklearn.linear_model._base object:
#
# class LinearRegression(sklearn.base.MultiOutputMixin, sklearn.base.RegressorMixin, LinearModel)
#  |  LinearRegression(
#  |      *,
#  |      fit_intercept=True,
#  |      copy_X=True,
#  |      tol=1e-06,
#  |      n_jobs=None,
#  |      positive=False
#  |  )
#  |
#  |  Ordinary least squares Linear Regression.
#  |
#  |  LinearRegression fits a linear model with coefficients w = (w1, ..., wp)
#  |  to minimize the residual sum of squares between the observed targets in
#  |  the dataset, and the targets predicted by the linear approximation.
#  |
#  |  Parameters
#  |  ----------
#  |  fit_intercept : bool, default=True
#  |      Whether to calculate the intercept for this model. If set
#  |      to False, no intercept will be used in calculations
#  |      (i.e. data is expected to be centered).
#  |
#  |  copy_X : bool, default=True
#  |      If True, X will be copied; else, it may be overwritten.
#  |
# ...

# %%
lm2.predict(X)
# Out:
# array([25.17108491, 23.76973578, 30.72188341, 29.02024518, 30.37609596,
#        23.85163281, 20.04797089, 21.50391804, 16.58099675, 19.97517353,
#        23.36935032, 20.02067188, 18.92871152, 19.4746917 , 20.81234314,
#        18.42822969, 19.34729633, 19.84777816, 14.98855456, 17.45456504,
#        16.0259169 , 19.62028642, 21.23092795, 18.23713663, 19.24719996,
#        16.28980732, 18.23713663, 20.36645933, 24.44311134, 26.07195221,
#        17.32716966, 20.59395107, 19.48379137, 17.21797363, 20.81234314,
#        19.32909699, 18.49192738, 18.57382441, 19.62938609, 25.3530783 ,
#        29.25683659, 26.9455205 , 21.47661903, 21.85880515, 20.56665206,
#        17.0450799 , 17.99144555, 20.21176495, 14.46987339, 16.31710633,
#        19.60208708, 20.98523687, 24.58870605, 19.92057552, 18.91961185,
#        31.30426226, 23.42394834, 27.3641053 , 21.25822696, 19.27449897,
#        17.58196041, 19.62938609, 24.08822422, 26.87272314, 29.98481016,
# ...

# %%
sns.jointplot(x=df['room_num'], y=df['price'], data=df, kind='reg')

# %%
X_multi = df.drop('price', axis=1) # X_multi is a new DataFrame that contains all the columns of df except for the 'price' column, which is the target variable we want to predict. The drop() method is used to remove the 'price' column from df, and axis=1 specifies that we want to drop a column (as opposed to a row).

# %%
X_multi.head()
# Out:
#    crime_rate  resid_area  air_qual  room_num   age  teachers  poor_prop  \
# 0    0.006300       32.31     0.538     6.575  65.2      24.7       4.98
# 1    0.026944       37.07     0.469     6.421  78.9      22.2       9.14
# 2    0.026924       37.07     0.469     7.185  61.1      22.2       4.03
# 3    0.031857       32.18     0.458     6.998  45.8      21.3       2.94
# 4    0.066770       32.18     0.458     7.147  54.2      21.3       5.33
#
#    n_hos_beds  n_hot_rooms  rainfall  avg_dist  airport_YES  waterbody_None  \
# 0       5.480     11.19200        23    4.0875            1               0
# 1       7.332     12.17280        42    4.9675            0               0
# 2       7.394     46.19856        38    4.9675            0               1
# 3       9.268     11.26720        45    6.0650            1               0
# 4       8.824     11.28960        55    6.0625            0               0
#
#    waterbody_River  waterbody_lake_and_river
# ...

# %%
y_multi = df['price'] # y_multi is a Series that contains the 'price' column from df, which is the target variable we want to predict in our multiple linear regression model. By assigning df['price'] to y_multi, we are creating a new variable that we can use as the dependent variable in our regression analysis.

# %%
y_multi.head()
# Out:
# 0    24.0
# 1    21.6
# 2    34.7
# 3    33.4
# 4    36.2
# Name: price, dtype: float64

# %%
X_multi_cons = sn.add_constant(X_multi) # adds a constant term to the predictor variables, which is necessary for the OLS regression model to include an intercept in the regression equation.

# %%
X_multi_cons.head()
# Out:
#    const  crime_rate  resid_area  air_qual  room_num   age  teachers  \
# 0    1.0    0.006300       32.31     0.538     6.575  65.2      24.7
# 1    1.0    0.026944       37.07     0.469     6.421  78.9      22.2
# 2    1.0    0.026924       37.07     0.469     7.185  61.1      22.2
# 3    1.0    0.031857       32.18     0.458     6.998  45.8      21.3
# 4    1.0    0.066770       32.18     0.458     7.147  54.2      21.3
#
#    poor_prop  n_hos_beds  n_hot_rooms  rainfall  avg_dist  airport_YES  \
# 0       4.98       5.480     11.19200        23    4.0875            1
# 1       9.14       7.332     12.17280        42    4.9675            0
# 2       4.03       7.394     46.19856        38    4.9675            0
# 3       2.94       9.268     11.26720        45    6.0650            1
# 4       5.33       8.824     11.28960        55    6.0625            0
#
#    waterbody_None  waterbody_River  waterbody_lake_and_river
# 0               0                1                         0
# ...

# %%
lm_multi = sn.OLS(y_multi, X_multi_cons).fit() # lm_multi is the fitted model object that contains the results of the multiple linear regression analysis. The OLS() function from the statsmodels library is used to fit the model, where y_multi is the dependent variable (the target variable we want to predict) and X_multi_cons is the independent variable (the predictor variables with a constant term added).

# %%
lm_multi.summary() # The summary() method is called on the fitted model object lm_multi to display a comprehensive summary of the regression results, including statistical measures such as coefficients, standard errors, t-values, p-values, and R-squared values, which help in interpreting the significance and strength of the relationships between the independent variables and the dependent variable in the multiple linear regression model.
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.721
# Model:                            OLS   Adj. R-squared:                  0.712
# Method:                 Least Squares   F-statistic:                     84.34
# Date:                Thu, 19 Mar 2026   Prob (F-statistic):          4.19e-125
# Time:                        00:41:14   Log-Likelihood:                -1516.6
# No. Observations:                 506   AIC:                             3065.
# Df Residuals:                     490   BIC:                             3133.
# Df Model:                          15
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# ### Using sklearn

# %%
lm3 = LinearRegression()

# %%
lm3.fit(X_multi, y_multi)
# Out:
# LinearRegression()

# %%
print(lm3.intercept_, lm3.coef_)
# Out:
# -6.23453913412888 [ 9.70998193e-03 -4.08746495e-02 -1.58973999e+01  4.01901676e+00
#  -5.71475069e-03  1.00700068e+00 -5.77271243e-01  3.29221139e-01
#   9.18675603e-02  1.61185504e-02 -1.21863952e+00  1.13151586e+00
#  -2.64086064e-01 -5.55404777e-01 -9.51641953e-01]

# %% [markdown]
# ### Test Train Split

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X_multi, y_multi, test_size=0.2, random_state=0) # The train_test_split() function from the sklearn library is used to split the dataset into training and testing sets. X_multi and y_multi are the independent and dependent variables, respectively. test_size=0.2 indicates that 20% of the data will be used for testing, while the remaining 80% will be used for training. random_state=0 ensures that the split is reproducible, meaning that the same random split will be generated each time the code is run.

# %%
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (404, 15) (102, 15) (404,) (102,)

# %%
lm_a = LinearRegression()

# %%
lm_a.fit(X_train, y_train) # The fit() method is called on the LinearRegression object lm_a to train the model using the training data (X_train and y_train). This method estimates the coefficients of the linear regression model based on the provided training data, allowing the model to learn the relationships between the independent variables (X_train) and the dependent variable (y_train). After fitting the model, it can be used to make predictions on new data or evaluate its performance on the test set.
# Out:
# LinearRegression()

# %%
y_test_a = lm_a.predict(X_test) # The predict() method is called on the fitted LinearRegression model lm_a to make predictions on the test set (X_test). This method uses the learned coefficients from the training phase to generate predicted values for the dependent variable based on the independent variables in X_test. The resulting y_test_a contains the predicted values for the test set, which can be compared to the actual values (y_test) to evaluate the performance of the model.

# %%
y_train_a = lm_a.predict(X_train) # The predict() method is called on the fitted LinearRegression model lm_a to make predictions on the training set (X_train). This method uses the learned coefficients from the training phase to generate predicted values for the dependent variable based on the independent variables in X_train. The resulting y_train_a contains the predicted values for the training set, which can be compared to the actual values (y_train) to evaluate the performance of the model on the training data.

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test, y_test_a) # The r2_score() function from the sklearn.metrics module is used to calculate the R-squared (coefficient of determination) score for the test set predictions. It compares the actual values (y_test) with the predicted values (y_test_a) to determine how well the model explains the variance in the dependent variable. A higher R-squared score indicates a better fit of the model to the data, with a score of 1 indicating a perfect fit and a score of 0 indicating that the model does not explain any of the variance in the dependent variable.
# Out:
# 0.5496468288205674

# %%
r2_score(y_train, y_train_a) # The r2_score() function is used again to calculate the R-squared score for the training set predictions. It compares the actual values (y_train) with the predicted values (y_train_a) to evaluate how well the model fits the training data. A higher R-squared score indicates a better fit of the model to the training data, with a score of 1 indicating a perfect fit and a score of 0 indicating that the model does not explain any of the variance in the dependent variable for the training set.
# Out:
# 0.756463540591123

# %% [markdown]
# ## Ridge Lasso

# %%
from sklearn import preprocessing

# %%
scalar = preprocessing.StandardScaler().fit(X_train) # The StandardScaler() function from the sklearn.preprocessing module is used to standardize the features in the training set (X_train). The fit() method is called on the StandardScaler object to compute the mean and standard deviation of each feature in X_train, which will be used for scaling the data. This step is important to ensure that all features are on the same scale, which can improve the performance of certain machine learning algorithms that are sensitive to feature scaling. After fitting the scaler, it can be applied to both the training and test sets to transform the features accordingly.

# %%
X_train_s = scalar.transform(X_train) # The transform() method is called on the fitted StandardScaler object (scalar) to scale the features in the training set (X_train). This method applies the standardization transformation to each feature in X_train using the mean and standard deviation computed during the fit() step. The resulting x_train_scaled contains the standardized features for the training set, which can be used for training machine learning models that require feature scaling.

# %%
X_test_s = scalar.transform(X_test) # The transform() method is called again on the fitted StandardScaler object (scalar) to scale the features in the test set (X_test). This ensures that the same scaling transformation applied to the training set is also applied to the test set, maintaining consistency in feature scaling between the two datasets. The resulting x_test_scaled contains the standardized features for the test set, which can be used for making predictions and evaluating the performance of machine learning models that require feature scaling.

# %%
from sklearn.linear_model import Ridge

# %%
lm_r = Ridge(alpha=0.5) # The Ridge() function from the sklearn.linear_model module is used to create a Ridge regression model object (lm_r) with a specified regularization strength (alpha=0.5). Ridge regression is a linear regression technique that includes a regularization term to prevent overfitting by adding a penalty to the coefficients of the model. The alpha parameter controls the strength of the regularization, with higher values leading to stronger regularization and smaller coefficients.

# %%
lm_r.fit(X_train_s, y_train) # The fit() method is called on the Ridge regression model object (lm_r) to train the model using the standardized training data (X_train_s and y_train). This method estimates the coefficients of the Ridge regression model based on the provided training data, allowing the model to learn the relationships between the independent variables (X_train_s) and the dependent variable (y_train) while applying regularization to prevent overfitting. After fitting the model, it can be used to make predictions on new data or evaluate its performance on the test set.
# Out:
# Ridge(alpha=0.5)

# %%
r2_score(y_test, lm_r.predict(X_test_s)) # The r2_score() function is used to calculate the R-squared score for the Ridge regression model's predictions on the test set. The predict() method of the fitted Ridge regression model (lm_r) is called with the standardized test data (X_test_s) to generate predicted values for the dependent variable. The r2_score() function then compares these predicted values with the actual values (y_test) to evaluate how well the Ridge regression model explains the variance in the dependent variable for the test set. A higher R-squared score indicates a better fit of the model to the data.
# Out:
# 0.5494276259189227

# %%
from sklearn.model_selection import validation_curve

# %%
validation_curve?
# Out:
# Signature:
# validation_curve(
#     estimator,
#     X,
#     y,
#     *,
#     param_name,
#     param_range,
#     groups=None,
#     cv=None,
#     scoring=None,
#     n_jobs=None,
#     pre_dispatch='all',
#     verbose=0,
#     error_score=nan,
#     fit_params=None,
#     params=None,
# )
# Docstring:
# Validation curve.
#
# Determine training and test scores for varying parameter values.
#
# Compute scores for an estimator with different values of a specified
# parameter. This is similar to grid search with one parameter. However, this
# will also compute training scores and is merely a utility for plotting the
# results.
#
# Read more in the :ref:`User Guide <validation_curve>`.
#
# Parameters
# ----------
# estimator : object type that implements the "fit" method
#     An object of that type which is cloned for each validation. It must
#     also implement "predict" unless `scoring` is a callable that doesn't
#     rely on "predict" to compute a score.
#
# ...

# %%
param_range = np.logspace(-2, 8, 100) # The np.logspace() function is used to generate a range of values for the regularization parameter (alpha) in Ridge regression. The parameters -2 and 8 specify the exponent range for the logarithmic scale, meaning that the generated values will be between 10^-2 and 10^8. The third parameter, 100, indicates that 100 evenly spaced values will be generated within this range. This range of alpha values can be used to evaluate the performance of the Ridge regression model across different levels of regularization using techniques such as validation curves or grid search.

# %%
param_range
# Out:
# array([1.00000000e-02, 1.26185688e-02, 1.59228279e-02, 2.00923300e-02,
#        2.53536449e-02, 3.19926714e-02, 4.03701726e-02, 5.09413801e-02,
#        6.42807312e-02, 8.11130831e-02, 1.02353102e-01, 1.29154967e-01,
#        1.62975083e-01, 2.05651231e-01, 2.59502421e-01, 3.27454916e-01,
#        4.13201240e-01, 5.21400829e-01, 6.57933225e-01, 8.30217568e-01,
#        1.04761575e+00, 1.32194115e+00, 1.66810054e+00, 2.10490414e+00,
#        2.65608778e+00, 3.35160265e+00, 4.22924287e+00, 5.33669923e+00,
#        6.73415066e+00, 8.49753436e+00, 1.07226722e+01, 1.35304777e+01,
#        1.70735265e+01, 2.15443469e+01, 2.71858824e+01, 3.43046929e+01,
#        4.32876128e+01, 5.46227722e+01, 6.89261210e+01, 8.69749003e+01,
#        1.09749877e+02, 1.38488637e+02, 1.74752840e+02, 2.20513074e+02,
#        2.78255940e+02, 3.51119173e+02, 4.43062146e+02, 5.59081018e+02,
#        7.05480231e+02, 8.90215085e+02, 1.12332403e+03, 1.41747416e+03,
# ...

# %%
train_scores, test_scores = validation_curve(Ridge(), X_train_s, y_train, param_name='alpha', param_range=param_range, scoring='r2') # The validation_curve() function from the sklearn.model_selection module is used to evaluate the performance of the Ridge regression model across a range of values for the regularization parameter (alpha). The function takes the Ridge() model, standardized training data (X_train_s and y_train), the name of the parameter to vary ('alpha'), the range of parameter values (param_range), and the scoring metric ('r2') as inputs. It returns two arrays: train_scores, which contains the R-squared scores for the training set at each value of alpha, and test_scores, which contains the R-squared scores for the test set at each value of alpha. These scores can be used to analyze how the model's performance changes with different levels of regularization and to select an optimal value for alpha.

# %%
print(train_scores)
print("---------------test_scores-----------------")
print(test_scores)
# Out:
# [[7.49308183e-01 7.62593562e-01 7.52614692e-01 7.82225880e-01
#   7.45875174e-01]
#  [7.49308182e-01 7.62593561e-01 7.52614692e-01 7.82225879e-01
#   7.45875174e-01]
#  [7.49308181e-01 7.62593560e-01 7.52614691e-01 7.82225879e-01
#   7.45875173e-01]
#  [7.49308179e-01 7.62593559e-01 7.52614690e-01 7.82225878e-01
#   7.45875171e-01]
#  [7.49308177e-01 7.62593557e-01 7.52614688e-01 7.82225876e-01
#   7.45875169e-01]
#  [7.49308173e-01 7.62593554e-01 7.52614685e-01 7.82225873e-01
#   7.45875166e-01]
#  [7.49308167e-01 7.62593549e-01 7.52614680e-01 7.82225869e-01
#   7.45875161e-01]
#  [7.49308157e-01 7.62593541e-01 7.52614673e-01 7.82225863e-01
#   7.45875153e-01]
#  [7.49308141e-01 7.62593528e-01 7.52614661e-01 7.82225852e-01
#   7.45875140e-01]
#  [7.49308116e-01 7.62593507e-01 7.52614642e-01 7.82225836e-01
#   7.45875119e-01]
#  [7.49308076e-01 7.62593475e-01 7.52614612e-01 7.82225809e-01
#   7.45875086e-01]
#  [7.49308013e-01 7.62593423e-01 7.52614563e-01 7.82225767e-01
# ...

# %%
train_mean = np.mean(train_scores, axis=1) # The np.mean() function is used to calculate the mean of the training scores across the different values of alpha. The axis=1 parameter specifies that the mean should be calculated along the columns (i.e., for each value of alpha), resulting in a 1D array (train_mean) that contains the average R-squared score for the training set at each value of alpha.
test_mean = np.mean(test_scores, axis=1) # The np.mean() function is used to calculate the mean of the test scores across the different values of alpha. The axis=1 parameter specifies that the mean should be calculated along the columns (i.e., for each value of alpha), resulting in a 1D array (test_mean) that contains the average R-squared score for the test set at each value of alpha.

# %%
train_mean
# Out:
# array([7.58523498e-01, 7.58523497e-01, 7.58523497e-01, 7.58523495e-01,
#        7.58523493e-01, 7.58523490e-01, 7.58523485e-01, 7.58523477e-01,
#        7.58523464e-01, 7.58523444e-01, 7.58523412e-01, 7.58523360e-01,
#        7.58523278e-01, 7.58523148e-01, 7.58522941e-01, 7.58522613e-01,
#        7.58522091e-01, 7.58521264e-01, 7.58519954e-01, 7.58517881e-01,
#        7.58514608e-01, 7.58509449e-01, 7.58501337e-01, 7.58488624e-01,
#        7.58468778e-01, 7.58437939e-01, 7.58390294e-01, 7.58317184e-01,
#        7.58205904e-01, 7.58038114e-01, 7.57787823e-01, 7.57418928e-01,
#        7.56882274e-01, 7.56112225e-01, 7.55022582e-01, 7.53501620e-01,
#        7.51405871e-01, 7.48552508e-01, 7.44710818e-01, 7.39594455e-01,
#        7.32857675e-01, 7.24099833e-01, 7.12882142e-01, 6.98758266e-01,
#        6.81315795e-01, 6.60220910e-01, 6.35256625e-01, 6.06348401e-01,
#        5.73578738e-01, 5.37199021e-01, 4.97645830e-01, 4.55558481e-01,
# ...

# %%
test_mean
# Out:
# array([ 0.73762673,  0.73762726,  0.73762792,  0.73762876,  0.73762982,
#         0.73763115,  0.73763284,  0.73763496,  0.73763763,  0.737641  ,
#         0.73764524,  0.73765057,  0.73765728,  0.73766571,  0.73767628,
#         0.73768953,  0.7377061 ,  0.73772676,  0.73775247,  0.73778431,
#         0.73782356,  0.73787163,  0.73793003,  0.73800021,  0.73808335,
#         0.73817999,  0.73828942,  0.73840879,  0.73853182,  0.73864699,
#         0.73873526,  0.73876704,  0.7386986 ,  0.7384677 ,  0.73798848,
#         0.73714527,  0.73578521,  0.73370971,  0.73066565,  0.72633824,
#         0.72034927,  0.71226477,  0.70161591,  0.68793358,  0.67079272,
#         0.6498575 ,  0.62491771,  0.5959108 ,  0.56293286,  0.52624819,
#         0.48630559,  0.44375725,  0.3994633 ,  0.35446023,  0.30988366,
#         0.2668561 ,  0.22636804,  0.18918399,  0.15579354,  0.12641096,
#         0.10101223,  0.07939272,  0.06122927,  0.04613581,  0.03370695,
# ...

# %%
max(test_mean)
# Out:
# np.float64(0.7387670425382201)

# %%
sns.jointplot(x=np.log(param_range), y=test_mean) # The sns.jointplot() function from the seaborn library is used to create a joint plot that visualizes the relationship between the logarithm of the regularization parameter values (param_range) and the corresponding mean R-squared scores for the test set (test_mean). The x-axis represents the log-transformed alpha values, while the y-axis represents the mean R-squared scores. This plot can help identify trends in model performance across different levels of regularization and assist in selecting an optimal alpha value for Ridge regression.

# %%
np.where(test_mean == max(test_mean)) # The np.where() function is used to find the index of the maximum value in the test_mean array. By comparing test_mean with its maximum value (max(test_mean)), we can identify the index or indices where the maximum R-squared score occurs. This information can be useful for determining which value of the regularization parameter (alpha) corresponds to the best performance of the Ridge regression model on the test set.
# Out:
# (array([31]),)

# %%
# find the np.where(test_mean == max(test_mean))
param_range[31] # The index 31 is used to access the value of alpha in the param_range array that corresponds to the maximum R-squared score found in the test_mean array. By using this index, we can identify the specific value of the regularization parameter (alpha) that yields the best performance for the Ridge regression model on the test set.
# Out:
# np.float64(13.530477745798061)

# %%
lm_r_best = Ridge(alpha=param_range[31]) # The Ridge regression model is instantiated with the optimal value of alpha (param_range[31]) that corresponds to the maximum R-squared score found in the test_mean array. This model (lm_r_best) is now configured to use the best regularization strength for making predictions and evaluating performance on the test set.

# %%
lm_r_best.fit(X_train_s, y_train) # The fit() method is called on the Ridge regression model object (lm_r_best) to train the model using the standardized training data (X_train_s and y_train). This method estimates the coefficients of the Ridge regression model based on the provided training data, allowing the model to learn the relationships between the independent variables (X_train_s) and the dependent variable (y_train) while applying regularization with the optimal alpha value. After fitting the model, it can be used to make predictions on new data or evaluate its performance on the test set.
# Out:
# Ridge(alpha=np.float64(13.530477745798061))

# %%
r2_score(y_test, lm_r_best.predict(X_test_s)) # The r2_score() function is used to calculate the R-squared score for the Ridge regression model (lm_r_best) with the optimal alpha value. The predict() method of the fitted model is called with the standardized test data (X_test_s) to generate predicted values for the dependent variable. The r2_score() function then compares these predicted values with the actual values (y_test) to evaluate how well the Ridge regression model with the optimal regularization strength explains the variance in the dependent variable for the test set. A higher R-squared score indicates a better fit of the model to the data.
# Out:
# 0.543780838951176

# %%
r2_score(y_train, lm_r_best.predict(X_train_s)) # The r2_score() function is used to calculate the R-squared score for the Ridge regression model (lm_r_best) with the optimal alpha value. The predict() method of the fitted model is called with the standardized training data (X_train_s) to generate predicted values for the dependent variable. The r2_score() function then compares these predicted values with the actual values (y_test) to evaluate how well the Ridge regression model with the optimal regularization strength explains the variance in the dependent variable for the training set. A higher R-squared score indicates a better fit of the model to the data.
# Out:
# 0.755728571771995

# %%
from sklearn.linear_model import Lasso

# %%
lm_l = Lasso(alpha=0.4) # The Lasso() function from the sklearn.linear_model module is used to create a Lasso regression model object (lm_l) with a specified regularization strength (alpha=0.4). Lasso regression is a linear regression technique that includes a regularization term to prevent overfitting by adding a penalty to the absolute values of the coefficients of the model. The alpha parameter controls the strength of the regularization, with higher values leading to stronger regularization and smaller coefficients, potentially resulting in some coefficients being exactly zero, which can be useful for feature selection.

# %%
lm_l.fit(X_train_s, y_train)
# Out:
# Lasso(alpha=0.4)

# %%
r2_score(y_test, lm_l.predict(X_test_s))
# Out:
# 0.5150841547786357

# %%
lm_l_best = Lasso(alpha=param_range[31])

# %%
lm_l_best.fit(X_train_s, y_train)
# Out:
# Lasso(alpha=np.float64(13.530477745798061))

# %%
r2_score(y_test, lm_l_best.predict(X_test_s))
# Out:
# -0.0011193237204489837

# %%
r2_score(y_train, lm_l_best.predict(X_train_s))
# Out:
# 0.0
